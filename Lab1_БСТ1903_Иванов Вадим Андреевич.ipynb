# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы БСТ1903 Иванов Вадим Андреевич
# ### Задание №1

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Задание №2

# %%
import random
def generateMatrix(m = 50, n = 50, min_limit = -250, max_limit = 1006):
    a = [[0] * n for i in range(m)]
    for i in range(m):
        for j in range(n):        
                a[i][j] = random.randint(min_limit, max_limit)    
    return a
    for row in a:
        print(' '.join([str(elem) for elem in row]))
newMatrix = generateMatrix()
print(newMatrix)
# Out:
# [[35, 553, 459, -34, 769, 844, 872, 950, -164, 340, 786, -112, -85, 619, 890, 789, -9, 141, 393, 956, -114, 776, 244, 24, 550, 539, 361, -129, 125, -175, 187, 279, 611, -181, 883, 171, 959, -249, 404, 854, 993, 217, 816, 801, 53, 227, -88, 207, 182, 712], [954, 364, 450, 782, 456, 126, 795, 996, 892, 383, 117, 212, 737, 988, 618, 647, -184, 56, 966, -78, 994, 183, -66, 381, 934, 615, 175, 859, -3, -18, -74, 846, 399, 417, 502, 1, 720, -39, 331, -140, 309, 895, 304, 759, 529, 277, 498, 163, 414, 900], [562, 247, -59, 336, 569, -207, 623, -241, -55, 618, 156, 465, -198, 879, 38, 773, 725, 798, 910, 15, 608, 799, 420, 195, 127, 167, 776, 710, 582, 739, -42, 863, 164, 331, 633, 96, 202, 736, -144, 292, 582, 797, 395, 960, 116, 675, 1001, -52, 670, 450], [319, 790, 314, 903, 676, 672, 949, 419, 778, 505, 502, 762, 569, -138, -20, -104, 484, 628, 949, 929, 862, 359, -123, 986, -145, 340, 930, 30, 720, 298, 354, 50, 528, 978, 985, 508, 652, 118, -195, 5, 119, 901, -111, 941, 959, 970, -75, 
# ...

# %% [markdown]
# ### Задание №3

# %% [markdown]
# #### Сортировка выбором

# %%
import time
def selectionSort(matrix):
    for row in matrix:
        for i in range(len(row)):
            minI = i
            for j in range(i + 1, len(row)):
                if row[j] < row[minI]:
                    minI = j
            row[i], row[minI] = row[minI], row[i]
        print(row)
        
start = time.time()
newMatrix = generateMatrix(5, 5, -250, 1006)
print("Исходная матрица")
for row in newMatrix:
    print(row)
print("Отсортированная матрица")
selectionSort(newMatrix)
print("Время выполнения:", time.time() - start)
# Out:
# Исходная матрица
# [675, 224, 198, 744, 446]
# [122, -71, 537, 694, -7]
# [356, 493, 149, 187, 415]
# [255, -1, 701, 438, -42]
# [-73, 612, 302, 225, 668]
# Отсортированная матрица
# [198, 224, 446, 675, 744]
# [-71, -7, 122, 537, 694]
# [149, 187, 356, 415, 493]
# [-42, -1, 255, 438, 701]
# [-73, 225, 302, 612, 668]
# Время выполнения: 0.0010068416595458984

# %% [markdown]
# #### Сортировка вставкой

# %%
import time
def inSort(matrix):  
    for row in matrix:
        for i in range(1, len(row)):
            item_to_insert = row[i]
            j = i - 1
            while j >= 0 and row[j] > item_to_insert:
                row[j + 1] = row[j]
                j -= 1
            row[j + 1] = item_to_insert
        print(row)
        
start = time.time()
newMatrix = generateMatrix(5, 5, -250, 1006)
print("Исходная матрица")
for row in newMatrix:
    print(row)
print("Отсортированная матрица")
inSort(newMatrix)
print("Время выполнения:", time.time() - start)
# Out:
# Исходная матрица
# [-167, 537, 671, 435, 1001]
# [408, 173, 160, 692, 811]
# [372, 140, 634, 991, 585]
# [532, 26, 830, 342, 394]
# [997, 176, 883, 693, 671]
# Отсортированная матрица
# [-167, 435, 537, 671, 1001]
# [160, 173, 408, 692, 811]
# [140, 372, 585, 634, 991]
# [26, 342, 394, 532, 830]
# [176, 671, 693, 883, 997]
# Время выполнения: 0.0009999275207519531

# %% [markdown]
# #### Сортировка обменом

# %%
import time
def bubbleSort(matrix):  
    for row in matrix:
        swapped = True
        while swapped:
            swapped = False
            for i in range(len(row) - 1):
                if row[i] > row[i + 1]:
                    row[i], row[i + 1] = row[i + 1], row[i]
                    swapped = True
        print(row)
        
start = time.time()
newMatrix = generateMatrix(5, 5, -250, 1006)
print("Исходная матрица")
for row in newMatrix:
    print(row)
print("Отсортированная матрица")
bubbleSort(newMatrix)
print("Время выполнения:", time.time() - start)
# Out:
# Исходная матрица
# [794, 153, 458, 743, -236]
# [506, 698, 214, 699, 862]
# [96, 530, 414, 202, 314]
# [-249, 844, 137, 69, 115]
# [-27, 612, -39, 360, 428]
# Отсортированная матрица
# [-236, 153, 458, 743, 794]
# [214, 506, 698, 699, 862]
# [96, 202, 314, 414, 530]
# [-249, 69, 115, 137, 844]
# [-39, -27, 360, 428, 612]
# Время выполнения: 0.0

# %% [markdown]
# #### Сортировка Шелла

# %%
def shellSort(matrix):
    for row in matrix:
        inc = len(row) // 2
        while inc:
            for i, el in enumerate(row):
                while i >= inc and row[i - inc] > el:
                    row[i] = row[i - inc]
                    i -= inc
                row[i] = el
            inc = 1 if inc == 2 else int(inc * 5.0 / 11)
        print(row)
        
start = time.time()
newMatrix = generateMatrix(5, 5, -250, 1006)
print("Исходная матрица")
for row in newMatrix:
    print(row)
print("Отсортированная матрица")
shellSort(newMatrix)
print("Время выполнения:", time.time() - start)
# Out:
# Исходная матрица
# [209, 194, 375, -231, -33]
# [636, 62, 849, 550, 515]
# [211, -180, 639, -155, -170]
# [835, 493, 787, 174, 151]
# [624, 13, 983, 462, 537]
# Отсортированная матрица
# [-231, -33, 194, 209, 375]
# [62, 515, 550, 636, 849]
# [-180, -170, -155, 211, 639]
# [151, 174, 493, 787, 835]
# [13, 462, 537, 624, 983]
# Время выполнения: 0.0

# %% [markdown]
# #### Турнирная сортировка

# %%
import time
def tourSort(arr):
    tree = [None] * 2 * (len(arr) + len(arr) % 2)
    index = len(tree) - len(arr) - len(arr) % 2
    
    for i, v in enumerate(arr):
        tree[index + i] = (i, v)
    
    for j in range(len(arr)):
        n = len(arr)
        index = len(tree) - len(arr) - len(arr) % 2
        while index > -1:
            n = (n + 1) // 2
            for i in range(n):
                i = max(index + i * 2, 1) # на последней итерация index + i * 2 = 0
                if tree[i] != None and tree[i + 1] != None:
                    if tree[i][1] < tree[i + 1][1]:
                        tree[i // 2] = tree[i]
                    else:
                        tree[i // 2] = tree[i + 1]
                else:
                    tree[i // 2] = tree[i] if tree[i] != None else tree[i + 1]
            index -= n
            
        index, x = tree[0]
        arr[j] = x
        tree[len(tree) - len(arr) - len(arr) % 2 + index] = None
        
start = time.time()
newMatrix = generateMatrix(5, 5, -250, 1006)
print("Исходная матрица")
for row in newMatrix:
    print(row)
print("Отсортированная матрица")
for row in newMatrix:
    tourSort(row)
    print(row)
print("Время выполнения:", time.time() - start)
# Out:
# Исходная матрица
# [747, 835, 564, 385, 585]
# [108, 501, 636, 108, 441]
# [56, 813, 232, -170, 162]
# [774, 183, 359, 669, 972]
# [355, -164, 468, 938, 301]
# Отсортированная матрица
# [385, 564, 585, 747, 835]
# [108, 108, 441, 501, 636]
# [-170, 56, 162, 232, 813]
# [183, 359, 669, 774, 972]
# [-164, 301, 355, 468, 938]
# Время выполнения: 0.0

# %% [markdown]
# #### Быстрая сортировка

# %%
import time
def quickSort(matrix): 
    def partition(nums, low, high):     
        pivot = nums[(low + high) // 2]
        i = low - 1
        j = high + 1
        while True:
            i += 1
            while nums[i] < pivot:
                i += 1

            j -= 1
            while nums[j] > pivot:
                j -= 1

            if i >= j:
                return j
            nums[i], nums[j] = nums[j], nums[i]
    for row in matrix:        
        def _quick_sort(items, low, high):
            if low < high:                
                split_index = partition(items, low, high)
                _quick_sort(items, low, split_index)
                _quick_sort(items, split_index + 1, high)

        _quick_sort(row, 0, len(row) - 1)
        print(row)
        
start = time.time()
newMatrix = generateMatrix(5, 5, -250, 1006)
print("Исходная матрица")
for row in newMatrix:
    print(row)
print("Отсортированная матрица")
quickSort(newMatrix)
print("Время выполнения:", time.time() - start)
# Out:
# Исходная матрица
# [205, -93, 470, 4, 719]
# [939, 845, 746, 274, 367]
# [81, 474, 954, -46, 141]
# [640, 741, -73, -196, 495]
# [-12, -110, 16, 850, 588]
# Отсортированная матрица
# [-93, 4, 205, 470, 719]
# [274, 367, 746, 845, 939]
# [-46, 81, 141, 474, 954]
# [-196, -73, 495, 640, 741]
# [-110, -12, 16, 588, 850]
# Время выполнения: 0.0

# %% [markdown]
# #### Пирамидальная сортировка

# %%
import time
def heapSort(matrix):  
    def heapify(nums, heap_size, root_index):  
        largest = root_index
        left_child = (2 * root_index) + 1
        right_child = (2 * root_index) + 2
        if left_child < heap_size and nums[left_child] > nums[largest]:
            largest = left_child
        if right_child < heap_size and nums[right_child] > nums[largest]:
            largest = right_child
        if largest != root_index:
            nums[root_index], nums[largest] = nums[largest], nums[root_index]
            heapify(nums, heap_size, largest)
    for row in matrix:
        n = len(row)
        for i in range(n, -1, -1):
            heapify(row, n, i)
        for i in range(n - 1, 0, -1):
            row[i], row[0] = row[0], row[i]
            heapify(row, i, 0)
        print(row)
        
start = time.time()
newMatrix = generateMatrix(5, 5, -250, 1006)
print("Исходная матрица")
for row in newMatrix:
    print(row)
print("Отсортированная матрица")
heapSort(newMatrix)
print("Время выполнения:", time.time() - start)
# Out:
# Исходная матрица
# [-47, 238, 66, 355, 233]
# [-177, 239, 523, -228, 151]
# [253, 818, 447, 790, 247]
# [-100, -170, 808, 561, 819]
# [263, 61, 416, 36, 762]
# Отсортированная матрица
# [-47, 66, 233, 238, 355]
# [-228, -177, 151, 239, 523]
# [247, 253, 447, 790, 818]
# [-170, -100, 561, 808, 819]
# [36, 61, 263, 416, 762]
# Время выполнения: 0.0

# %% [markdown]
# #### Стандартная функция сортировки

# %%
start = time.time()
newMatrix = generateMatrix(5, 5, -250, 1006)
print("Исходная матрица")
for row in newMatrix:
    print(row)
print("Отсортированная матрица")
for row in newMatrix:
    row.sort()
    print(row)
print("Время выполнения:", time.time() - start)
# Out:
# Исходная матрица
# [971, 285, 877, 487, 38]
# [605, 162, 244, 715, 381]
# [470, 197, -246, 602, 362]
# [12, 736, 685, 339, 499]
# [114, 203, 98, 559, 24]
# Отсортированная матрица
# [38, 285, 487, 877, 971]
# [162, 244, 381, 605, 715]
# [-246, 197, 362, 470, 602]
# [12, 339, 499, 685, 736]
# [24, 98, 114, 203, 559]
# Время выполнения: 0.0
